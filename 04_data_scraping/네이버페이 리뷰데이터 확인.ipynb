# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import koreanize_matplotlib

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)

# %%
data = pd.read_csv('./data/naverpay_reviews_20250430_0530_확인.csv')
data
# Out:
#         userName                                            content  score  \
# 0            홍성용                    본인확인을 위한 휴대전화 인증이 안됩니다. 고쳐 주세요.      1
# 1            고현진  솔직히 이번 업데이트를 왜 이런 식으로 했는지 이해가 불가능하고, 이전 것이 더 낫...      1
# 2      홍보 리뷰만 보임  저장된 카드로 결제 가능해서 실물카드 안 갖고 다녔는데 매장결제는 가능한데 QR결제...      1
# 3            주헌영                                       왜 합쳤냐 불편해죽겠네      1
# 4        Ryu Kay                 갤럭시s21 최근 네이버페이 삼성페이 결제가 거의 불가능합니다      1
# ..           ...                                                ...    ...
# 132       ABCD a  페이 결제할 때 광고 작작 좀 뜨게 해요. 결제하려고 주는데 광고창 떠있어서 끄고 ...      1
# 133      박자를타고난자  에티켓 알림설정 시간을 설정했는데도 새벽1시에 부동산관심매물 알림이와요 앱버그입니까...      2
# 134   Yarore Lee  업데이트 승인 누가했냐. 최악이다. 삼성페이 개 벌레처럼 만들엇네. 이제 점유율 높...      1
# 135  김영준 (무기력중증)                핸트폰초기화 새로설치 인증 구글구버전 업대이트 해도안댄다구요~~      1
# 136          닭둘기        UI로 미로 게임을 만드는 아이디어가 정말 창의적이네요. 이 게임 재밌습니다.      2
#
#      thumbsUpCount reviewCreatedVersion                   at  \
# ...

# %%
data['score'].value_counts()
# Out:
# score
# 1    82
# 5    25
# 2    11
# 3    10
# 4     9
# Name: count, dtype: int64

# %%
data[data['score'] == 5]['content']
# Out:
# 16                                                                                                                                                                                                                                                                                                                                                    좋아요
# 18                                                                                                                                                                                                                                                                                                                                업체의 신용 근거하여 편리하게 입금합니다.
# ...

# %%
data[(data['score'] == 4) | (data['score'] == 3) | (data['score'] == 2)]['content']
# Out:
# 5                                                                                                                                                                                                                          저는 좋다고 생각 합니다 결제 포인트 는 자유 자재로 할수 있기 때문 입니다
# 9                                                                                                                                                                                                                            항상 잘 되던 포인트 적립이 왜 갑자기 결제할 때마다 적립이 안되나요??
# 10                                                                                                                                                               네이버 리서치 리포트들을 볼때 화면을 가로로 전환할수 없어요. 글씨가 작아서 확대해서 보다보면 자꾸 손으로 좌우 왔다갔다 해야되서 가로로 보는게 편한데 전혀 가로로 볼 수 없네요.
# ...

# %%
data[data['score'] == 1]['content']
# Out:
# 0                                                                                                                                                                           본인확인을 위한 휴대전화 인증이 안됩니다. 고쳐 주세요.
# 1                                                                                                                                     솔직히 이번 업데이트를 왜 이런 식으로 했는지 이해가 불가능하고, 이전 것이 더 낫고, 이번 것은 헷갈려서 도저히 욕나오네~
# 2                                             저장된 카드로 결제 가능해서 실물카드 안 갖고 다녔는데 매장결제는 가능한데 QR결제는 왜 안되는거죠?카드인식 안되는 곳이라 처음으로 QR결제하려는데 포인트.머니 떠있길래 카드로 바꾸고 몇 번이나 시도했는데 할때마다 화면에 '할인코드 적용안됨'이라고만 뜨고 결제 안돼서 그냥 나왔어요
# 3                                                                                                                                                                                              왜 합쳤냐 불편해죽겠네
# ...
