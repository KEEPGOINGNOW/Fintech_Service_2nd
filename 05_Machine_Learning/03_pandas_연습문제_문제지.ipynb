# %%
import pandas as pd

# %%
# dataframe
data = {'country': ['Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
        'population': [11.3, 64.3, 81.3, 16.9, 64.9],
        'area': [30510, 671308, 357050, 41526, 244820],
        'capital': ['Brussels', 'Paris', 'Berlin', 'Amsterdam', 'London']}
countries = pd.DataFrame(data)
countries = countries.set_index('country') # 인덱스 지정
countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brussels
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Belgium to United Kingdom
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   population  5 non-null      float64
#  1   area        5 non-null      int64
#  2   capital     5 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 160.0+ bytes

# %% [markdown]
# ---
#
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구밀도를 의미하는 `density` 칼럼을 추가하세요. (주의: 현재 'population' 칼럼은 100만 단위로 표기되어 있습니다)
#
# </div>

# %%
countries['density'] = countries['population'] * 1000000 / countries['area']
countries
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.3   30510   Brussels  370.370370       1.355755
# France                64.3  671308      Paris   95.783158       0.350618
# Germany               81.3  357050     Berlin  227.699202       0.833502
# Netherlands           16.9   41526  Amsterdam  406.973944       1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구밀도가 300을 초과하는 국가(country)의 수도(capital)과 인구(population)을 선택해주세요.
#
# </div>

# %%
countries[countries['density'] > 300][['capital','population']]
# Out:
#                capital  population
# country
# Belgium       Brussels        11.3
# Netherlands  Amsterdam        16.9

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'density_ratio' 칼럼을 추가해주세요. (density_ratio = 인구밀도/평균 인구밀도)
# </div>

# %%
mean_density = countries['density'].mean()
countries['density_ratio'] = countries['density'] / mean_density
countries
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.3   30510   Brussels  370.370370       1.355755
# France                64.3  671308      Paris   95.783158       0.350618
# Germany               81.3  357050     Berlin  227.699202       0.833502
# Netherlands           16.9   41526  Amsterdam  406.973944       1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 영국(United Kingdom)의 수도(capital)를 'Cambridge'로 변경해주세요.
# </div>

# %%
countries.loc['United Kingdom', 'capital'] = 'Cambridge'
countries
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.3   30510   Brussels  370.370370       1.355755
# France                64.3  671308      Paris   95.783158       0.350618
# Germany               81.3  357050     Berlin  227.699202       0.833502
# Netherlands           16.9   41526  Amsterdam  406.973944       1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인구 밀도가 100 초과, 300 미만인 국가들을 표시해주세요.
# </div>

# %%
countries[(countries['density'] > 100) & (countries['density'] < 300)]
# Out:
#                 population    area    capital     density  density_ratio
# country
# Germany               81.3  357050     Berlin  227.699202       0.833502
# United Kingdom        64.9  244820  Cambridge  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 수도가 7글자 이상인 국가들을 표시해주세요. (힌트: string의 len( )를 사용하세요.)
# </div>

# %%
countries[countries.iloc[:,2].str.len() >= 7]
# Out:
#                 population    area    capital     density  density_ratio
# country
# Belgium               11.3   30510   Brussels  370.370370       1.355755
# Netherlands           16.9   41526  Amsterdam  406.973944       1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721       0.970382

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 수도에 'am' 이 포함되는 국가들을 표시해주세요. (힌트: string의 contains( )를 사용하세요.)
# </div>

# %%
countries[countries['capital'].str.contains('am')]
# Out:
#                 population    area    capital     density  density_ratio
# country
# Netherlands           16.9   41526  Amsterdam  406.973944       1.489744
# United Kingdom        64.9  244820  Cambridge  265.092721       0.970382

# %% [markdown]
# # 영화리뷰 데이터에서 자료 찾기

# %% [markdown]
# movie_title_data.tsv 읽어오기

# %% [markdown]
# https://drive.google.com/file/d/1cvBtLVyfhfodJK-BXWqBLcopyus9HOIc/view?usp=sharing

# %%
import pandas as pd
titles = pd.read_csv('./data/movie_title_data.tsv', sep='\t')
titles
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14064\2014120005.py:2: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   titles = pd.read_csv('./data/movie_title_data.tsv', sep='\t')
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8407394  tt9916848  tvEpisode              Episode #3.17
# 8407395  tt9916850  tvEpisode              Episode #3.19
# 8407396  tt9916852  tvEpisode              Episode #3.20
# 8407397  tt9916856      short                   The Wind
# 8407398  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# 2                   Pauvre Pierrot       0      1892      \N              4
# 3                      Un bon bock       0      1892      \N             12
# 4                 Blacksmith Scene       0      1893      \N              1
# ...                            ...     ...       ...     ...            ...
# 8407394              Episode #3.17       0      2010      \N             \N
# 8407395              Episode #3.19       0      2010      \N             \N
# 8407396              Episode #3.20       0      2010      \N             \N
# 8407397                   The Wind       0      2015      \N             27
# 8407398  Horrid Henry Knows It All       0      2014      \N             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 8407394         Action,Drama,Family
# 8407395         Action,Drama,Family
# 8407396         Action,Drama,Family
# 8407397                       Short
# 8407398  Adventure,Animation,Comedy
#
# [8407399 rows x 9 columns]

# %%
titles.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8407399 entries, 0 to 8407398
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   tconst          8407399 non-null  object
#  1   titleType       8407399 non-null  object
#  2   primaryTitle    8407385 non-null  object
#  3   originalTitle   8407385 non-null  object
#  4   isAdult         8407399 non-null  object
#  5   startYear       8407399 non-null  object
#  6   endYear         8407399 non-null  object
#  7   runtimeMinutes  8407399 non-null  object
#  8   genres          8407389 non-null  object
# dtypes: object(9)
# memory usage: 577.3+ MB

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8407399 entries, 0 to 8407398
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 577.3+ MB

# %%
titles['startYear'].unique()
# Out:
# array([1894, 1892, 1893, 1895, 1896, 1898, 1897, 1900, 1899, 1901, 1902,
#        1903, 1905, 1904, 1912, 1907, 1906, 1908, 1910, 1909, 1914, 1911,
#        1913, 1915, 1919, 1916, 1917, 1918, 1936, 1925, 1920, 1922, 1921,
#        1923, 2019, 1924, 1928, 1926, 1927, 1929, 2000, 1993, 1935, 2014,
#        1930, 1942, 1934, 1931, 1932, 1939, 1937, 1933, 1950, 1938, 1951,
#        1945, 1946, 1996, 1940, 1944, 1949, 1947, 1941, 1952, 1970, 1957,
#        1943, 1959, 1948, 2001, 1953, 2008, 1954, 1965, 1983, 1980, 1973,
#        1961, 1995, 1955, 1962, 1958, 1956, 1977, 1960, 1964, 1967, 1968,
#        1963, 1986, 1971, 1969, 1972, 1966, 2021, 2002, 1976, 1990, 2020,
#        1979, 1974, 1978, 1981, 1988, 1975, 1989, '1971', '1972', '1970',
#        '1974', '1973', '1976', '1969', '1968', '1985', '\\N', '1981',
#        '2009', '1980', '1986', '1965', '1987', '1975', '1978', '1967',
#        '1990', '1977', '2010', '2018', '1979', '2007', '1989', '1983',
#        '1988', '1984', '1966', '1982', '1992', '1991', '1952', '1963',
#        '2001', '1961', '1994', '1993', '1964', '1957', '1999', '1995',
#        '2019', '2005', '1953', '2004', '1998', '1947', '2002', '1997',
#        '1959', '1996', '2017', '2000', '1945', '1956', '2021', '2013',
#        '2016', '2006', '2003', '1955', '1949', '2008', '1960', '1930',
#        '1938', '1929', '1944', '1935', '1962', '1919', '1951', '1914',
#        '1954', '1958', '1907', '1942', '1918', '1943', '1921', '1927',
#        '1941', '1939', '1940', '1937', '1950', '1946', '1916', '1948',
#        '1934', '1912', '1911', '1926', '1933', '1936', '1925', '1932',
#        '1928', '1917', '1920', '1931', '1913', '1895', '1922', '1923',
#        '1924', '1900', '1908', '1915', '1910', '1897', '1905', '1909',
#        '1903', '1902', '1901', '1906', '1904', '1898', '1896', '1899',
#        '2012', '2014', '2020', '2015', '2011', '1894', '1892', '1893',
#        '1891', '1888', '1890', '2022', '1889', '2023', '2024', '2025',
#        '2027', '2026', '2028', '1878', '1877', '1882', '1881', '1887',
#        '1874', '1883', '1885'], dtype=object)

# %%
titles.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      14
# originalTitle     14
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            10
# dtype: int64

# %%
titles.loc[titles['startYear'] == '\\N', 'startYear'] = '0'

# %%
titles['startYear'] = titles['startYear'].apply(str)

# %%
titles['startYear'].unique()
# Out:
# array(['1894', '1892', '1893', '1895', '1896', '1898', '1897', '1900',
#        '1899', '1901', '1902', '1903', '1905', '1904', '1912', '1907',
#        '1906', '1908', '1910', '1909', '1914', '1911', '1913', '1915',
#        '1919', '1916', '1917', '1918', '1936', '1925', '1920', '1922',
#        '1921', '1923', '2019', '1924', '1928', '1926', '1927', '1929',
#        '2000', '1993', '1935', '2014', '1930', '1942', '1934', '1931',
#        '1932', '1939', '1937', '1933', '1950', '1938', '1951', '1945',
#        '1946', '1996', '1940', '1944', '1949', '1947', '1941', '1952',
#        '1970', '1957', '1943', '1959', '1948', '2001', '1953', '2008',
#        '1954', '1965', '1983', '1980', '1973', '1961', '1995', '1955',
#        '1962', '1958', '1956', '1977', '1960', '1964', '1967', '1968',
#        '1963', '1986', '1971', '1969', '1972', '1966', '2021', '2002',
#        '1976', '1990', '2020', '1979', '1974', '1978', '1981', '1988',
#        '1975', '1989', '1985', '0', '2009', '1987', '2010', '2018',
#        '2007', '1984', '1982', '1992', '1991', '1994', '1999', '2005',
#        '2004', '1998', '1997', '2017', '2013', '2016', '2006', '2003',
#        '2012', '2015', '2011', '1891', '1888', '1890', '2022', '1889',
#        '2023', '2024', '2025', '2027', '2026', '2028', '1878', '1877',
#        '1882', '1881', '1887', '1874', '1883', '1885'], dtype=object)

# %%
titles['startYear'] = titles['startYear'].apply("int16")

# %%
titles.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8407399 entries, 0 to 8407398
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   tconst          8407399 non-null  object
#  1   titleType       8407399 non-null  object
#  2   primaryTitle    8407385 non-null  object
#  3   originalTitle   8407385 non-null  object
#  4   isAdult         8407399 non-null  object
#  5   startYear       8407399 non-null  int16
#  6   endYear         8407399 non-null  object
#  7   runtimeMinutes  8407399 non-null  object
#  8   genres          8407389 non-null  object
# dtypes: int16(1), object(8)
# memory usage: 529.2+ MB

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: titles 데이터프레임에는 몇 개의 영화가 기록되어 있나요?
# </div>

# %%
print(titles['tconst'].count())
# Out:
# 8407399

# %%
len(titles)
# Out:
# 8407399

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: titles에서 가장 빠른 시기에 제작된 영화 두 개를 표시하세요.  힌트: .sort_values()
# </div>

# %%
import numpy as np
titles2 = titles.copy()

# %%
# \\N을 처리해야됨
titles2['startYear'].value_counts()
# Out:
# startYear
# 0       1023113
# 2018     403334
# 2017     402283
# 2019     384861
# 2016     382509
#          ...
# 1877          1
# 1882          1
# 1874          1
# 1883          1
# 1885          1
# Name: count, Length: 150, dtype: int64

# %%
movie_startYear = titles2['startYear'].replace([r'\N', r'\\N'], np.nan).dropna().astype(int)
pastest_year = movie_startYear.sort_values().head(2).unique()

# %%
titles3 = titles.copy()

# %%
titles3['startYear'] = titles3['startYear'].replace([r'\N', r'\\N'], np.nan).astype('float')

# %%
# titles3[titles3['startYear'].isin(pastest_year)]

# %%
titles[titles["startYear"] > 0].sort_values(by="startYear").head(2)
# Out:
#              tconst titleType       primaryTitle      originalTitle isAdult  \
# 5329521   tt3155794     short   Passage de Venus   Passage de Venus       0
# 3488807  tt14495706     short  La Rosace Magique  La Rosace Magique       0
#
#          startYear endYear runtimeMinutes             genres
# 5329521       1874      \N              1  Documentary,Short
# 3488807       1877      \N              1    Animation,Short

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 제목(originalTitle)이 "Hamlet"인 영화는 몇 개가 있나요?
# </div>

# %%
titles4 = titles.copy()

# %%
titles4['originalTitle'].isna().value_counts()
# Out:
# originalTitle
# False    8407385
# True          14
# Name: count, dtype: int64

# %%
# 14개면 dropna해도 무방하다고 생각
titles4['originalTitle'] = titles4['originalTitle'].dropna()

# %%
len(titles4['originalTitle'][(titles4['originalTitle'].isna() == False) & (titles4['originalTitle'].str.contains('Hamlet') == True]))
# Out:
# 417

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 제목(originalTitle)이 "Treasure Island"인 영화를 제작년도(startYear)의 오름차순에 따라 표시하세요
# </div>

# %%
titles4['startYear'] = titles4['startYear'].replace([r'\N', r'\\N'], np.nan).dropna().astype(int)

# %%
titles4[(titles4['originalTitle'] == 'Treasure Island') & (titles4['startYear'] != 0)].sort_values(by='startYear')
# Out:
#              tconst  titleType     primaryTitle    originalTitle isAdult  \
# 2511      tt0002538      short  Treasure Island  Treasure Island       0
# 5032142   tt2440348      short  Treasure Island  Treasure Island       0
# 9589      tt0009721      movie  Treasure Island  Treasure Island       0
# 11620     tt0011785      movie  Treasure Island  Treasure Island       0
# 25459     tt0025907      movie  Treasure Island  Treasure Island       0
# ...             ...        ...              ...              ...     ...
# 6917550   tt6727462  tvEpisode  Treasure Island  Treasure Island       0
# 3809301  tt15075064  tvEpisode  Treasure Island  Treasure Island       0
# 1574276  tt11064450      movie  Treasure Island  Treasure Island       0
# 4323630   tt1659339      movie  Treasure Island  Treasure Island       0
# 7838572   tt8709864   tvSeries  Treasure Island  Treasure Island       0
#
#          startYear endYear runtimeMinutes                 genres
# 2511        1912.0      \N             \N        Adventure,Short
# 5032142     1913.0      \N             \N         Short,Thriller
# 9589        1917.0      \N             60              Adventure
# 11620       1920.0      \N             76              Adventure
# 25459       1934.0      \N            110       Adventure,Family
# ...            ...     ...            ...                    ...
# 6917550     2019.0      \N             71  Drama,Fantasy,Mystery
# 3809301     2021.0      \N             \N       Animation,Comedy
# 1574276        NaN      \N             \N              Adventure
# 4323630        NaN      \N             \N              Adventure
# 7838572        NaN      \N             \N             Reality-TV
#
# [70 rows x 9 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 1950년에서 1959년 사이 몇 개의 영화가 만들어졌나요?(1950 <= 제작년도 <= 1959)
# </div>

# %%
len(titles4['originalTitle'][(titles4['startYear'] >= 1950) & (titles4['startYear'] <= 1959)])
# Out:
# np.int64(118649)

# %% [markdown]
# # 타이타닉 자료에서 그룹별 연산하기

# %% [markdown]
# 원격 DB에 접속해서 titanic 데이터베이스 안에 있는 p_info, t_info, survived 테이블을 불러와 합치고 아래의 문제를 풀어보세요.<br>
# <id:kict00, pw:kict00, ip:221.155.18.165:3306, db:titanic>

# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb
# Out:
# <function pymysql.install_as_MySQLdb()>

# %%
# MySQL DB에 접속
engine = create_engine('mysql+pymysql://kict13:kict13@221.155.18.165:3306/titanic')
conn = engine.connect()

# %%
passenger = pd.read_sql('p_info', con=conn)
ticket = pd.read_sql('t_info', con=conn)
survived  = pd.read_sql('survived', con=conn)
conn.close
# Out:
# <bound method Connection.close of <sqlalchemy.engine.base.Connection object at 0x000001814A07FEE0>>

# %%
passenger.head()
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                           Allen, Mr. William Henry    male
#
#     Age  SibSp  Parch
# 0  22.0      1      0
# 1  38.0      1      0
# 2  26.0      0      0
# 3  35.0      1      0
# 4  35.0      0      0

# %%
ticket.head()
# Out:
#    PassengerId            Ticket  Pclass     Fare Cabin Embarked
# 0            1         A/5 21171       3   7.2500  None        S
# 1            2          PC 17599       1  71.2833   C85        C
# 2            3  STON/O2. 3101282       3   7.9250  None        S
# 3            4            113803       1  53.1000  C123        S
# 4            5            373450       3   8.0500  None        S

# %%
survived.head()
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1
# 3            4         1
# 4            5         0

# %%
# merge
joined_df = pd.merge(passenger, ticket, how='inner', on='PassengerId')

# %%
df = pd.merge(joined_df, survived, how='inner', on='PassengerId')

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 상위 5개 행을 출력하세요.
# </div>

# %%
df.head()
# Out:
#    PassengerId                                               Name     Sex  \
# 0            1                            Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2            3                             Heikkinen, Miss. Laina  female
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                           Allen, Mr. William Henry    male
#
#     Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# 0  22.0      1      0         A/5 21171       3   7.2500  None        S
# 1  38.0      1      0          PC 17599       1  71.2833   C85        C
# 2  26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3  35.0      1      0            113803       1  53.1000  C123        S
# 4  35.0      0      0            373450       3   8.0500  None        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 정보(info)를 출력하세요.
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Name         891 non-null    object
#  2   Sex          891 non-null    object
#  3   Age          714 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Ticket       891 non-null    object
#  7   Pclass       891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Survived     891 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 기술통계(describe)를 확인하세요.
# </div>

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch      Pclass  \
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594    2.308642
# std     257.353842   14.526497    1.102743    0.806057    0.836071
# min       1.000000    0.420000    0.000000    0.000000    1.000000
# 25%     223.500000   20.125000    0.000000    0.000000    2.000000
# 50%     446.000000   28.000000    0.000000    0.000000    3.000000
# 75%     668.500000   38.000000    1.000000    0.000000    3.000000
# max     891.000000   80.000000    8.000000    6.000000    3.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 처음 100명의 데이터를 출력하세요.
# </div>

# %%
# df.head(100)
# 너무 많은 행이 나오면 다운될 수 있으니 설정
pd.set_option('display.max_rows', 100)


df.iloc[:100,:]
# Out:
#     PassengerId                                               Name     Sex  \
# 0             1                            Braund, Mr. Owen Harris    male
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4             5                           Allen, Mr. William Henry    male
# 5             6                                   Moran, Mr. James    male
# 6             7                            McCarthy, Mr. Timothy J    male
# 7             8                     Palsson, Master. Gosta Leonard    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female
# 12           13                     Saundercock, Mr. William Henry    male
# 13           14                        Andersson, Mr. Anders Johan    male
# 14           15               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15           16                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16           17                               Rice, Master. Eugene    male
# 17           18                       Williams, Mr. Charles Eugene    male
# 18           19  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19           20                            Masselmani, Mrs. Fatima  female
# 20           21                               Fynney, Mr. Joseph J    male
# 21           22                              Beesley, Mr. Lawrence    male
# 22           23                        McGowan, Miss. Anna "Annie"  female
# 23           24                       Sloper, Mr. William Thompson    male
# 24           25                      Palsson, Miss. Torborg Danira  female
# 25           26  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female
# 26           27                            Emir, Mr. Farred Chehab    male
# 27           28                     Fortune, Mr. Charles Alexander    male
# 28           29                      O'Dwyer, Miss. Ellen "Nellie"  female
# 29           30                                Todoroff, Mr. Lalio    male
# 30           31                           Uruchurtu, Don. Manuel E    male
# 31           32     Spencer, Mrs. William Augustus (Marie Eugenie)  female
# 32           33                           Glynn, Miss. Mary Agatha  female
# 33           34                              Wheadon, Mr. Edward H    male
# 34           35                            Meyer, Mr. Edgar Joseph    male
# 35           36                     Holverson, Mr. Alexander Oskar    male
# 36           37                                   Mamee, Mr. Hanna    male
# 37           38                           Cann, Mr. Ernest Charles    male
# 38           39                 Vander Planke, Miss. Augusta Maria  female
# 39           40                        Nicola-Yarred, Miss. Jamila  female
# 40           41     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female
# 41           42  Turpin, Mrs. William John Robert (Dorothy Ann ...  female
# 42           43                                Kraeff, Mr. Theodor    male
# 43           44           Laroche, Miss. Simonne Marie Anne Andree  female
# 44           45                      Devaney, Miss. Margaret Delia  female
# 45           46                           Rogers, Mr. William John    male
# 46           47                                  Lennon, Mr. Denis    male
# 47           48                          O'Driscoll, Miss. Bridget  female
# 48           49                                Samaan, Mr. Youssef    male
# 49           50      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female
# 50           51                         Panula, Master. Juha Niilo    male
# 51           52                       Nosworthy, Mr. Richard Cater    male
# 52           53           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female
# 53           54  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female
# 54           55                     Ostby, Mr. Engelhart Cornelius    male
# 55           56                                  Woolner, Mr. Hugh    male
# 56           57                                  Rugg, Miss. Emily  female
# 57           58                                Novel, Mr. Mansouer    male
# 58           59                       West, Miss. Constance Mirium  female
# 59           60                 Goodwin, Master. William Frederick    male
# 60           61                              Sirayanian, Mr. Orsen    male
# 61           62                                Icard, Miss. Amelie  female
# 62           63                        Harris, Mr. Henry Birkhardt    male
# 63           64                              Skoog, Master. Harald    male
# 64           65                              Stewart, Mr. Albert A    male
# 65           66                           Moubarek, Master. Gerios    male
# 66           67                       Nye, Mrs. (Elizabeth Ramell)  female
# 67           68                           Crease, Mr. Ernest James    male
# 68           69                    Andersson, Miss. Erna Alexandra  female
# 69           70                                  Kink, Mr. Vincenz    male
# 70           71                         Jenkin, Mr. Stephen Curnow    male
# 71           72                         Goodwin, Miss. Lillian Amy  female
# 72           73                               Hood, Mr. Ambrose Jr    male
# 73           74                        Chronopoulos, Mr. Apostolos    male
# 74           75                                      Bing, Mr. Lee    male
# 75           76                            Moen, Mr. Sigurd Hansen    male
# 76           77                                  Staneff, Mr. Ivan    male
# 77           78                           Moutal, Mr. Rahamin Haim    male
# 78           79                      Caldwell, Master. Alden Gates    male
# 79           80                           Dowdell, Miss. Elizabeth  female
# 80           81                               Waelens, Mr. Achille    male
# 81           82                        Sheerlinck, Mr. Jan Baptist    male
# 82           83                     McDermott, Miss. Brigdet Delia  female
# 83           84                            Carrau, Mr. Francisco M    male
# 84           85                                Ilett, Miss. Bertha  female
# 85           86  Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female
# 86           87                             Ford, Mr. William Neal    male
# 87           88                      Slocovski, Mr. Selman Francis    male
# 88           89                         Fortune, Miss. Mabel Helen  female
# 89           90                             Celotti, Mr. Francesco    male
# 90           91                               Christmann, Mr. Emil    male
# 91           92                         Andreasson, Mr. Paul Edvin    male
# 92           93                        Chaffee, Mr. Herbert Fuller    male
# 93           94                            Dean, Mr. Bertram Frank    male
# 94           95                                  Coxon, Mr. Daniel    male
# 95           96                        Shorney, Mr. Charles Joseph    male
# 96           97                          Goldschmidt, Mr. George B    male
# 97           98                    Greenfield, Mr. William Bertram    male
# 98           99               Doling, Mrs. John T (Ada Julia Bone)  female
# 99          100                                  Kantor, Mr. Sinai    male
#
#       Age  SibSp  Parch            Ticket  Pclass      Fare        Cabin  \
# 0   22.00      1      0         A/5 21171       3    7.2500         None
# 1   38.00      1      0          PC 17599       1   71.2833          C85
# 2   26.00      0      0  STON/O2. 3101282       3    7.9250         None
# 3   35.00      1      0            113803       1   53.1000         C123
# 4   35.00      0      0            373450       3    8.0500         None
# 5     NaN      0      0            330877       3    8.4583         None
# 6   54.00      0      0             17463       1   51.8625          E46
# 7    2.00      3      1            349909       3   21.0750         None
# 8   27.00      0      2            347742       3   11.1333         None
# 9   14.00      1      0            237736       2   30.0708         None
# 10   4.00      1      1           PP 9549       3   16.7000           G6
# 11  58.00      0      0            113783       1   26.5500         C103
# 12  20.00      0      0         A/5. 2151       3    8.0500         None
# 13  39.00      1      5            347082       3   31.2750         None
# 14  14.00      0      0            350406       3    7.8542         None
# 15  55.00      0      0            248706       2   16.0000         None
# 16   2.00      4      1            382652       3   29.1250         None
# 17    NaN      0      0            244373       2   13.0000         None
# 18  31.00      1      0            345763       3   18.0000         None
# 19    NaN      0      0              2649       3    7.2250         None
# 20  35.00      0      0            239865       2   26.0000         None
# 21  34.00      0      0            248698       2   13.0000          D56
# 22  15.00      0      0            330923       3    8.0292         None
# 23  28.00      0      0            113788       1   35.5000           A6
# 24   8.00      3      1            349909       3   21.0750         None
# 25  38.00      1      5            347077       3   31.3875         None
# 26    NaN      0      0              2631       3    7.2250         None
# 27  19.00      3      2             19950       1  263.0000  C23 C25 C27
# 28    NaN      0      0            330959       3    7.8792         None
# 29    NaN      0      0            349216       3    7.8958         None
# 30  40.00      0      0          PC 17601       1   27.7208         None
# 31    NaN      1      0          PC 17569       1  146.5208          B78
# 32    NaN      0      0            335677       3    7.7500         None
# 33  66.00      0      0        C.A. 24579       2   10.5000         None
# 34  28.00      1      0          PC 17604       1   82.1708         None
# 35  42.00      1      0            113789       1   52.0000         None
# 36    NaN      0      0              2677       3    7.2292         None
# 37  21.00      0      0        A./5. 2152       3    8.0500         None
# 38  18.00      2      0            345764       3   18.0000         None
# 39  14.00      1      0              2651       3   11.2417         None
# 40  40.00      1      0              7546       3    9.4750         None
# 41  27.00      1      0             11668       2   21.0000         None
# 42    NaN      0      0            349253       3    7.8958         None
# 43   3.00      1      2     SC/Paris 2123       2   41.5792         None
# 44  19.00      0      0            330958       3    7.8792         None
# 45    NaN      0      0   S.C./A.4. 23567       3    8.0500         None
# 46    NaN      1      0            370371       3   15.5000         None
# 47    NaN      0      0             14311       3    7.7500         None
# 48    NaN      2      0              2662       3   21.6792         None
# 49  18.00      1      0            349237       3   17.8000         None
# 50   7.00      4      1           3101295       3   39.6875         None
# 51  21.00      0      0        A/4. 39886       3    7.8000         None
# 52  49.00      1      0          PC 17572       1   76.7292          D33
# 53  29.00      1      0              2926       2   26.0000         None
# 54  65.00      0      1            113509       1   61.9792          B30
# 55    NaN      0      0             19947       1   35.5000          C52
# 56  21.00      0      0        C.A. 31026       2   10.5000         None
# 57  28.50      0      0              2697       3    7.2292         None
# 58   5.00      1      2        C.A. 34651       2   27.7500         None
# 59  11.00      5      2           CA 2144       3   46.9000         None
# 60  22.00      0      0              2669       3    7.2292         None
# 61  38.00      0      0            113572       1   80.0000          B28
# 62  45.00      1      0             36973       1   83.4750          C83
# 63   4.00      3      2            347088       3   27.9000         None
# 64    NaN      0      0          PC 17605       1   27.7208         None
# 65    NaN      1      1              2661       3   15.2458         None
# 66  29.00      0      0        C.A. 29395       2   10.5000          F33
# 67  19.00      0      0         S.P. 3464       3    8.1583         None
# 68  17.00      4      2           3101281       3    7.9250         None
# 69  26.00      2      0            315151       3    8.6625         None
# 70  32.00      0      0        C.A. 33111       2   10.5000         None
# 71  16.00      5      2           CA 2144       3   46.9000         None
# 72  21.00      0      0      S.O.C. 14879       2   73.5000         None
# 73  26.00      1      0              2680       3   14.4542         None
# 74  32.00      0      0              1601       3   56.4958         None
# 75  25.00      0      0            348123       3    7.6500        F G73
# 76    NaN      0      0            349208       3    7.8958         None
# 77    NaN      0      0            374746       3    8.0500         None
# 78   0.83      0      2            248738       2   29.0000         None
# 79  30.00      0      0            364516       3   12.4750         None
# 80  22.00      0      0            345767       3    9.0000         None
# 81  29.00      0      0            345779       3    9.5000         None
# 82    NaN      0      0            330932       3    7.7875         None
# 83  28.00      0      0            113059       1   47.1000         None
# 84  17.00      0      0        SO/C 14885       2   10.5000         None
# 85  33.00      3      0           3101278       3   15.8500         None
# 86  16.00      1      3        W./C. 6608       3   34.3750         None
# 87    NaN      0      0   SOTON/OQ 392086       3    8.0500         None
# 88  23.00      3      2             19950       1  263.0000  C23 C25 C27
# 89  24.00      0      0            343275       3    8.0500         None
# 90  29.00      0      0            343276       3    8.0500         None
# 91  20.00      0      0            347466       3    7.8542         None
# 92  46.00      1      0       W.E.P. 5734       1   61.1750          E31
# 93  26.00      1      2         C.A. 2315       3   20.5750         None
# 94  59.00      0      0            364500       3    7.2500         None
# 95    NaN      0      0            374910       3    8.0500         None
# 96  71.00      0      0          PC 17754       1   34.6542           A5
# 97  23.00      0      1          PC 17759       1   63.3583      D10 D12
# 98  34.00      0      1            231919       2   23.0000         None
# 99  34.00      1      0            244367       2   26.0000         None
#
#    Embarked  Survived
# 0         S         0
# 1         C         1
# 2         S         1
# 3         S         1
# 4         S         0
# 5         Q         0
# 6         S         0
# 7         S         0
# 8         S         1
# 9         C         1
# 10        S         1
# 11        S         1
# 12        S         0
# 13        S         0
# 14        S         0
# 15        S         1
# 16        Q         0
# 17        S         1
# 18        S         0
# 19        C         1
# 20        S         0
# 21        S         1
# 22        Q         1
# 23        S         1
# 24        S         0
# 25        S         1
# 26        C         0
# 27        S         0
# 28        Q         1
# 29        S         0
# 30        C         0
# 31        C         1
# 32        Q         1
# 33        S         0
# 34        C         0
# 35        S         0
# 36        C         1
# 37        S         0
# 38        S         0
# 39        C         1
# 40        S         0
# 41        S         0
# 42        C         0
# 43        C         1
# 44        Q         1
# 45        S         0
# 46        Q         0
# 47        Q         1
# 48        C         0
# 49        S         0
# 50        S         0
# 51        S         0
# 52        C         1
# 53        S         1
# 54        C         0
# 55        S         1
# 56        S         1
# 57        C         0
# 58        S         1
# 59        S         0
# 60        C         0
# 61     None         1
# 62        S         0
# 63        S         0
# 64        C         0
# 65        C         1
# 66        S         1
# 67        S         0
# 68        S         1
# 69        S         0
# 70        S         0
# 71        S         0
# 72        S         0
# 73        C         0
# 74        S         1
# 75        S         0
# 76        S         0
# 77        S         0
# 78        S         1
# 79        S         1
# 80        S         0
# 81        S         1
# 82        Q         1
# 83        S         0
# 84        S         1
# 85        S         1
# 86        S         0
# 87        S         0
# 88        S         1
# 89        S         0
# 90        S         0
# 91        S         0
# 92        S         0
# 93        S         0
# 94        S         0
# 95        S         0
# 96        C         0
# 97        C         1
# 98        S         1
# 99        S         0

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스가 10~20인 데이터를 출력하세요.
# </div>

# %%
df.loc[10:20, :]
# Out:
#     PassengerId                                               Name     Sex  \
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female
# 12           13                     Saundercock, Mr. William Henry    male
# 13           14                        Andersson, Mr. Anders Johan    male
# 14           15               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15           16                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16           17                               Rice, Master. Eugene    male
# 17           18                       Williams, Mr. Charles Eugene    male
# 18           19  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19           20                            Masselmani, Mrs. Fatima  female
# 20           21                               Fynney, Mr. Joseph J    male
#
#      Age  SibSp  Parch     Ticket  Pclass     Fare Cabin Embarked  Survived
# 10   4.0      1      1    PP 9549       3  16.7000    G6        S         1
# 11  58.0      0      0     113783       1  26.5500  C103        S         1
# 12  20.0      0      0  A/5. 2151       3   8.0500  None        S         0
# 13  39.0      1      5     347082       3  31.2750  None        S         0
# 14  14.0      0      0     350406       3   7.8542  None        S         0
# 15  55.0      0      0     248706       2  16.0000  None        S         1
# 16   2.0      4      1     382652       3  29.1250  None        Q         0
# 17   NaN      0      0     244373       2  13.0000  None        S         1
# 18  31.0      1      0     345763       3  18.0000  None        S         0
# 19   NaN      0      0       2649       3   7.2250  None        C         1
# 20  35.0      0      0     239865       2  26.0000  None        S         0

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 컬럼 이름을 모두 출력하세요.
# </div>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Pclass', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 데이터의 shape를 확인하세요.
# </div>

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age' 컬럼의 평균을 구하세요.
# </div>

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Survived' 컬럼의 고유값을 확인하세요.
# </div>

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 30 이상인 승객만 출력하세요.
# </div>

# %%
# float이므로 데이터타입 변경 없이 가능
df['Age'].dtype
# Out:
# dtype('float64')

# %%
df[df['Age'] >= 30]
# Out:
#      PassengerId                                               Name     Sex  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# 6              7                            McCarthy, Mr. Timothy J    male
# 11            12                           Bonnell, Miss. Elizabeth  female
# ..           ...                                                ...     ...
# 873          874                        Vander Cruyssen, Mr. Victor    male
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 881          882                                 Markun, Mr. Johann    male
# 885          886               Rice, Mrs. William (Margaret Norton)  female
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch    Ticket  Pclass     Fare Cabin Embarked  Survived
# 1    38.0      1      0  PC 17599       1  71.2833   C85        C         1
# 3    35.0      1      0    113803       1  53.1000  C123        S         1
# 4    35.0      0      0    373450       3   8.0500  None        S         0
# 6    54.0      0      0     17463       1  51.8625   E46        S         0
# 11   58.0      0      0    113783       1  26.5500  C103        S         1
# ..    ...    ...    ...       ...     ...      ...   ...      ...       ...
# 873  47.0      0      0    345765       3   9.0000  None        S         0
# 879  56.0      0      1     11767       1  83.1583   C50        C         1
# 881  33.0      0      0    349257       3   7.8958  None        S         0
# 885  39.0      0      5    382652       3  29.1250  None        Q         0
# 890  32.0      0      0    370376       3   7.7500  None        Q         0
#
# [330 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별이 'female'이고 생존한 승객만 출력하세요.
# </div>

# %%
df[(df['Sex'] == 'female') & (df['Survived'] == 1)]
# Out:
#      PassengerId                                               Name     Sex  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 8              9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9             10                Nasser, Mrs. Nicholas (Adele Achem)  female
# ..           ...                                                ...     ...
# 874          875              Abelson, Mrs. Samuel (Hannah Wizosky)  female
# 875          876                   Najib, Miss. Adele Kiamie "Jane"  female
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 880          881       Shelley, Mrs. William (Imanita Parrish Hall)  female
# 887          888                       Graham, Miss. Margaret Edith  female
#
#       Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# 1    38.0      1      0          PC 17599       1  71.2833   C85        C
# 2    26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3    35.0      1      0            113803       1  53.1000  C123        S
# 8    27.0      0      2            347742       3  11.1333  None        S
# 9    14.0      1      0            237736       2  30.0708  None        C
# ..    ...    ...    ...               ...     ...      ...   ...      ...
# 874  28.0      1      0         P/PP 3381       2  24.0000  None        C
# 875  15.0      0      0              2667       3   7.2250  None        C
# 879  56.0      0      1             11767       1  83.1583   C50        C
# 880  25.0      0      1            230433       2  26.0000  None        S
# 887  19.0      0      0            112053       1  30.0000   B42        S
#
#      Survived
# 1           1
# 2           1
# 3           1
# 8           1
# 9           1
# ..        ...
# 874         1
# 875         1
# 879         1
# 880         1
# 887         1
#
# [233 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 10살 이하이고 요금이 20 이상인 승객을 출력하세요.
# </div>

# %%
df[(df['Age'] <= 10) & (df['Fare'] >= 20)]
# Out:
#      PassengerId                                             Name     Sex  \
# 7              8                   Palsson, Master. Gosta Leonard    male
# 16            17                             Rice, Master. Eugene    male
# 24            25                    Palsson, Miss. Torborg Danira  female
# 43            44         Laroche, Miss. Simonne Marie Anne Andree  female
# 50            51                       Panula, Master. Juha Niilo    male
# 58            59                     West, Miss. Constance Mirium  female
# 63            64                            Skoog, Master. Harald    male
# 78            79                    Caldwell, Master. Alden Gates    male
# 119          120                Andersson, Miss. Ellis Anna Maria  female
# 147          148                 Ford, Miss. Robina Maggie "Ruby"  female
# 164          165                     Panula, Master. Eino Viljami    male
# 165          166  Goldsmith, Master. Frank John William "Frankie"    male
# 171          172                             Rice, Master. Arthur    male
# 182          183            Asplund, Master. Clarence Gustaf Hugo    male
# 183          184                        Becker, Master. Richard F    male
# 184          185              Kink-Heilmann, Miss. Luise Gretchen  female
# 193          194                       Navratil, Master. Michel M    male
# 233          234                   Asplund, Miss. Lillian Gertrud  female
# 237          238                 Collyer, Miss. Marjorie "Lottie"  female
# 261          262                Asplund, Master. Edvin Rojj Felix    male
# 278          279                               Rice, Master. Eric    male
# 297          298                     Allison, Miss. Helen Loraine  female
# 305          306                   Allison, Master. Hudson Trevor    male
# 340          341                   Navratil, Master. Edmond Roger    male
# 374          375                       Palsson, Miss. Stina Viola  female
# 386          387                  Goodwin, Master. Sidney Leonard    male
# 419          420                        Van Impe, Miss. Catharina  female
# 445          446                        Dodge, Master. Washington    male
# 480          481                   Goodwin, Master. Harold Victor    male
# 530          531                         Quick, Miss. Phyllis May  female
# 535          536                           Hart, Miss. Eva Miriam  female
# 541          542             Andersson, Miss. Ingeborg Constanzia  female
# 549          550                   Davies, Master. John Morgan Jr    male
# 618          619                      Becker, Miss. Marion Louise  female
# 634          635                               Skoog, Miss. Mabel  female
# 642          643                    Skoog, Miss. Margit Elizabeth  female
# 720          721                Harper, Miss. Annie Jessie "Nina"  female
# 750          751                                Wells, Miss. Joan  female
# 787          788                        Rice, Master. George Hugh    male
# 788          789                       Dean, Master. Bertram Vere    male
# 813          814               Andersson, Miss. Ebba Iris Alfrida  female
# 819          820                     Skoog, Master. Karl Thorsten    male
# 824          825                     Panula, Master. Urho Abraham    male
# 827          828                            Mallet, Master. Andre    male
# 850          851          Andersson, Master. Sigvard Harald Elias    male
#
#        Age  SibSp  Parch           Ticket  Pclass      Fare    Cabin Embarked  \
# 7     2.00      3      1           349909       3   21.0750     None        S
# 16    2.00      4      1           382652       3   29.1250     None        Q
# 24    8.00      3      1           349909       3   21.0750     None        S
# 43    3.00      1      2    SC/Paris 2123       2   41.5792     None        C
# 50    7.00      4      1          3101295       3   39.6875     None        S
# 58    5.00      1      2       C.A. 34651       2   27.7500     None        S
# 63    4.00      3      2           347088       3   27.9000     None        S
# 78    0.83      0      2           248738       2   29.0000     None        S
# 119   2.00      4      2           347082       3   31.2750     None        S
# 147   9.00      2      2       W./C. 6608       3   34.3750     None        S
# 164   1.00      4      1          3101295       3   39.6875     None        S
# 165   9.00      0      2           363291       3   20.5250     None        S
# 171   4.00      4      1           382652       3   29.1250     None        Q
# 182   9.00      4      2           347077       3   31.3875     None        S
# 183   1.00      2      1           230136       2   39.0000       F4        S
# 184   4.00      0      2           315153       3   22.0250     None        S
# 193   3.00      1      1           230080       2   26.0000       F2        S
# 233   5.00      4      2           347077       3   31.3875     None        S
# 237   8.00      0      2       C.A. 31921       2   26.2500     None        S
# 261   3.00      4      2           347077       3   31.3875     None        S
# 278   7.00      4      1           382652       3   29.1250     None        Q
# 297   2.00      1      2           113781       1  151.5500  C22 C26        S
# 305   0.92      1      2           113781       1  151.5500  C22 C26        S
# 340   2.00      1      1           230080       2   26.0000       F2        S
# 374   3.00      3      1           349909       3   21.0750     None        S
# 386   1.00      5      2          CA 2144       3   46.9000     None        S
# 419  10.00      0      2           345773       3   24.1500     None        S
# 445   4.00      0      2            33638       1   81.8583      A34        S
# 480   9.00      5      2          CA 2144       3   46.9000     None        S
# 530   2.00      1      1            26360       2   26.0000     None        S
# 535   7.00      0      2     F.C.C. 13529       2   26.2500     None        S
# 541   9.00      4      2           347082       3   31.2750     None        S
# 549   8.00      1      1       C.A. 33112       2   36.7500     None        S
# 618   4.00      2      1           230136       2   39.0000       F4        S
# 634   9.00      3      2           347088       3   27.9000     None        S
# 642   2.00      3      2           347088       3   27.9000     None        S
# 720   6.00      0      1           248727       2   33.0000     None        S
# 750   4.00      1      1            29103       2   23.0000     None        S
# 787   8.00      4      1           382652       3   29.1250     None        Q
# 788   1.00      1      2        C.A. 2315       3   20.5750     None        S
# 813   6.00      4      2           347082       3   31.2750     None        S
# 819  10.00      3      2           347088       3   27.9000     None        S
# 824   2.00      4      1          3101295       3   39.6875     None        S
# 827   1.00      0      2  S.C./PARIS 2079       2   37.0042     None        C
# 850   4.00      4      2           347082       3   31.2750     None        S
#
#      Survived
# 7           0
# 16          0
# 24          0
# 43          1
# 50          0
# 58          1
# 63          0
# 78          1
# 119         0
# 147         0
# 164         0
# 165         1
# 171         0
# 182         0
# 183         1
# 184         1
# 193         1
# 233         1
# 237         1
# 261         1
# 278         0
# 297         0
# 305         1
# 340         1
# 374         0
# 386         0
# 419         0
# 445         1
# 480         0
# 530         1
# 535         1
# 541         0
# 549         1
# 618         1
# 634         0
# 642         0
# 720         1
# 750         1
# 787         0
# 788         1
# 813         0
# 819         0
# 824         0
# 827         1
# 850         0

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이가 결측치인 데이터를 출력하세요.
# </div>

# %%
# df['Age'].isna().sum()
df[df['Age'].isna()]
# Out:
#      PassengerId                                      Name     Sex  Age  \
# 5              6                          Moran, Mr. James    male  NaN
# 17            18              Williams, Mr. Charles Eugene    male  NaN
# 19            20                   Masselmani, Mrs. Fatima  female  NaN
# 26            27                   Emir, Mr. Farred Chehab    male  NaN
# 28            29             O'Dwyer, Miss. Ellen "Nellie"  female  NaN
# ..           ...                                       ...     ...  ...
# 859          860                          Razi, Mr. Raihed    male  NaN
# 863          864         Sage, Miss. Dorothy Edith "Dolly"  female  NaN
# 868          869               van Melkebeke, Mr. Philemon    male  NaN
# 878          879                        Laleff, Mr. Kristo    male  NaN
# 888          889  Johnston, Miss. Catherine Helen "Carrie"  female  NaN
#
#      SibSp  Parch      Ticket  Pclass     Fare Cabin Embarked  Survived
# 5        0      0      330877       3   8.4583  None        Q         0
# 17       0      0      244373       2  13.0000  None        S         1
# 19       0      0        2649       3   7.2250  None        C         1
# 26       0      0        2631       3   7.2250  None        C         0
# 28       0      0      330959       3   7.8792  None        Q         1
# ..     ...    ...         ...     ...      ...   ...      ...       ...
# 859      0      0        2629       3   7.2292  None        C         0
# 863      8      2    CA. 2343       3  69.5500  None        S         0
# 868      0      0      345777       3   9.5000  None        S         0
# 878      0      0      349217       3   7.8958  None        S         0
# 888      1      2  W./C. 6607       3  23.4500  None        S         0
#
# [177 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 나이를 기준으로 오름차순 정렬하세요.
# </div>

# %%
#df[df['Age'].isna() == False].sort_values(by='Age')
df.sort_values(by='Age')
# Out:
#      PassengerId                                      Name     Sex   Age  \
# 803          804           Thomas, Master. Assad Alexander    male  0.42
# 755          756                 Hamalainen, Master. Viljo    male  0.67
# 469          470             Baclini, Miss. Helene Barbara  female  0.75
# 644          645                    Baclini, Miss. Eugenie  female  0.75
# 78            79             Caldwell, Master. Alden Gates    male  0.83
# ..           ...                                       ...     ...   ...
# 859          860                          Razi, Mr. Raihed    male   NaN
# 863          864         Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# 868          869               van Melkebeke, Mr. Philemon    male   NaN
# 878          879                        Laleff, Mr. Kristo    male   NaN
# 888          889  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
#
#      SibSp  Parch      Ticket  Pclass     Fare Cabin Embarked  Survived
# 803      0      1        2625       3   8.5167  None        C         1
# 755      1      1      250649       2  14.5000  None        S         1
# 469      2      1        2666       3  19.2583  None        C         1
# 644      2      1        2666       3  19.2583  None        C         1
# 78       0      2      248738       2  29.0000  None        S         1
# ..     ...    ...         ...     ...      ...   ...      ...       ...
# 859      0      0        2629       3   7.2292  None        C         0
# 863      8      2    CA. 2343       3  69.5500  None        S         0
# 868      0      0      345777       3   9.5000  None        S         0
# 878      0      0      349217       3   7.8958  None        S         0
# 888      1      2  W./C. 6607       3  23.4500  None        S         0
#
# [891 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 요금을 기준으로 내림차순 정렬하고 상위 5명만 출력하세요.
# </div>

# %%
df.sort_values(by='Fare', ascending=False).head()
# Out:
#      PassengerId                                Name     Sex   Age  SibSp  \
# 737          738              Lesurer, Mr. Gustave J    male  35.0      0
# 679          680  Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 258          259                    Ward, Miss. Anna  female  35.0      0
# 438          439                   Fortune, Mr. Mark    male  64.0      1
# 88            89          Fortune, Miss. Mabel Helen  female  23.0      3
#
#      Parch    Ticket  Pclass      Fare        Cabin Embarked  Survived
# 737      0  PC 17755       1  512.3292         B101        C         1
# 679      1  PC 17755       1  512.3292  B51 B53 B55        C         1
# 258      0  PC 17755       1  512.3292         None        C         1
# 438      4     19950       1  263.0000  C23 C25 C27        S         0
# 88       2     19950       1  263.0000  C23 C25 C27        S         1

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별로 그룹화하여 생존률 평균을 구하세요.
# </div>

# %%
df[['Sex','Survived']].groupby('Sex').mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: Pclass별 평균 나이를 구하세요.
# </div>

# %%
df[['Pclass','Age']].groupby('Pclass').mean()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'에 10을 더한 값을 새로운 컬럼 'Age_plus_10'으로 추가하세요.
# </div>

# %%
df['Age_plus_10'] = df['Age'] + 10
display(df)
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# 0    22.0      1      0         A/5 21171       3   7.2500  None        S
# 1    38.0      1      0          PC 17599       1  71.2833   C85        C
# 2    26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3    35.0      1      0            113803       1  53.1000  C123        S
# 4    35.0      0      0            373450       3   8.0500  None        S
# ..    ...    ...    ...               ...     ...      ...   ...      ...
# 886  27.0      0      0            211536       2  13.0000  None        S
# 887  19.0      0      0            112053       1  30.0000   B42        S
# 888   NaN      1      2        W./C. 6607       3  23.4500  None        S
# 889  26.0      0      0            111369       1  30.0000  C148        C
# 890  32.0      0      0            370376       3   7.7500  None        Q
#
#      Survived  Age_plus_10
# 0           0         32.0
# 1           1         48.0
# 2           1         36.0
# 3           1         45.0
# 4           0         45.0
# ..        ...          ...
# 886         0         37.0
# 887         1         29.0
# 888         0          NaN
# 889         1         36.0
# 890         0         42.0
#
# [891 rows x 13 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'가 18 이상이면 '성인', 아니면 '미성년'으로 분류하는 컬럼을 추가하세요.
# </div>

# %%
df['isadult'] = df['Age'].apply(lambda x: '성인' if x >= 18 else '미성년')
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket  Pclass     Fare Cabin Embarked  \
# 0    22.0      1      0         A/5 21171       3   7.2500  None        S
# 1    38.0      1      0          PC 17599       1  71.2833   C85        C
# 2    26.0      0      0  STON/O2. 3101282       3   7.9250  None        S
# 3    35.0      1      0            113803       1  53.1000  C123        S
# 4    35.0      0      0            373450       3   8.0500  None        S
# ..    ...    ...    ...               ...     ...      ...   ...      ...
# 886  27.0      0      0            211536       2  13.0000  None        S
# 887  19.0      0      0            112053       1  30.0000   B42        S
# 888   NaN      1      2        W./C. 6607       3  23.4500  None        S
# 889  26.0      0      0            111369       1  30.0000  C148        C
# 890  32.0      0      0            370376       3   7.7500  None        Q
#
#      Survived  Age_plus_10 isadult
# 0           0         32.0      성인
# 1           1         48.0      성인
# 2           1         36.0      성인
# 3           1         45.0      성인
# 4           0         45.0      성인
# ..        ...          ...     ...
# 886         0         37.0      성인
# 887         1         29.0      성인
# 888         0          NaN     미성년
# 889         1         36.0      성인
# 890         0         42.0      성인
#
# [891 rows x 14 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Age'의 결측치를 평균으로 채우세요.
# </div>

# %%
df['Age']  = df['Age'].fillna(df['Age'].mean())
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Cabin' 컬럼의 결측치를 'Unknown'으로 채우세요.
# </div>

# %%
df['Cabin'] = df['Cabin'].fillna('Unknown')
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#            Age  SibSp  Parch            Ticket  Pclass     Fare    Cabin  \
# 0    22.000000      1      0         A/5 21171       3   7.2500  Unknown
# 1    38.000000      1      0          PC 17599       1  71.2833      C85
# 2    26.000000      0      0  STON/O2. 3101282       3   7.9250  Unknown
# 3    35.000000      1      0            113803       1  53.1000     C123
# 4    35.000000      0      0            373450       3   8.0500  Unknown
# ..         ...    ...    ...               ...     ...      ...      ...
# 886  27.000000      0      0            211536       2  13.0000  Unknown
# 887  19.000000      0      0            112053       1  30.0000      B42
# 888  29.699118      1      2        W./C. 6607       3  23.4500  Unknown
# 889  26.000000      0      0            111369       1  30.0000     C148
# 890  32.000000      0      0            370376       3   7.7500  Unknown
#
#     Embarked  Survived  Age_plus_10 isadult
# 0          S         0         32.0      성인
# 1          C         1         48.0      성인
# 2          S         1         36.0      성인
# 3          S         1         45.0      성인
# 4          S         0         45.0      성인
# ..       ...       ...          ...     ...
# 886        S         0         37.0      성인
# 887        S         1         29.0      성인
# 888        S         0          NaN     미성년
# 889        C         1         36.0      성인
# 890        Q         0         42.0      성인
#
# [891 rows x 14 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 중복된 'Ticket' 값을 제거하고 몇 개가 남는지 출력하세요.
# </div>

# %%
len(df['Ticket'].drop_duplicates())
# Out:
# 681

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 'Embarked' 컬럼의 고유값과 각각의 개수를 출력하세요.
# </div>

# %%
print(df['Embarked'].unique())
print(df['Embarked'].value_counts())
# Out:
# ['S' 'C' 'Q' None]
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스를 'PassengerId'로 설정하세요.
# </div>

# %%
df.set_index('PassengerId')
# Out:
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# 887                                      Montvila, Rev. Juozas    male
# 888                               Graham, Miss. Margaret Edith  female
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female
# 890                                      Behr, Mr. Karl Howell    male
# 891                                        Dooley, Mr. Patrick    male
#
#                    Age  SibSp  Parch            Ticket  Pclass     Fare  \
# PassengerId
# 1            22.000000      1      0         A/5 21171       3   7.2500
# 2            38.000000      1      0          PC 17599       1  71.2833
# 3            26.000000      0      0  STON/O2. 3101282       3   7.9250
# 4            35.000000      1      0            113803       1  53.1000
# 5            35.000000      0      0            373450       3   8.0500
# ...                ...    ...    ...               ...     ...      ...
# 887          27.000000      0      0            211536       2  13.0000
# 888          19.000000      0      0            112053       1  30.0000
# 889          29.699118      1      2        W./C. 6607       3  23.4500
# 890          26.000000      0      0            111369       1  30.0000
# 891          32.000000      0      0            370376       3   7.7500
#
#                Cabin Embarked  Survived  Age_plus_10 Age_classfication
# PassengerId
# 1            Unknown        S         0         32.0                성인
# 2                C85        C         1         48.0                성인
# 3            Unknown        S         1         36.0                성인
# 4               C123        S         1         45.0                성인
# 5            Unknown        S         0         45.0                성인
# ...              ...      ...       ...          ...               ...
# 887          Unknown        S         0         37.0                성인
# 888              B42        S         1         29.0                성인
# 889          Unknown        S         0          NaN               미성년
# 890             C148        C         1         36.0                성인
# 891          Unknown        Q         0         42.0                성인
#
# [891 rows x 13 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 인덱스를 초기화하세요.
# </div>

# %%
df.reset_index(drop=True)
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#            Age  SibSp  Parch            Ticket  Pclass     Fare    Cabin  \
# 0    22.000000      1      0         A/5 21171       3   7.2500  Unknown
# 1    38.000000      1      0          PC 17599       1  71.2833      C85
# 2    26.000000      0      0  STON/O2. 3101282       3   7.9250  Unknown
# 3    35.000000      1      0            113803       1  53.1000     C123
# 4    35.000000      0      0            373450       3   8.0500  Unknown
# ..         ...    ...    ...               ...     ...      ...      ...
# 886  27.000000      0      0            211536       2  13.0000  Unknown
# 887  19.000000      0      0            112053       1  30.0000      B42
# 888  29.699118      1      2        W./C. 6607       3  23.4500  Unknown
# 889  26.000000      0      0            111369       1  30.0000     C148
# 890  32.000000      0      0            370376       3   7.7500  Unknown
#
#     Embarked  Survived  Age_plus_10 Age_classfication
# 0          S         0         32.0                성인
# 1          C         1         48.0                성인
# 2          S         1         36.0                성인
# 3          S         1         45.0                성인
# 4          S         0         45.0                성인
# ..       ...       ...          ...               ...
# 886        S         0         37.0                성인
# 887        S         1         29.0                성인
# 888        S         0          NaN               미성년
# 889        C         1         36.0                성인
# 890        Q         0         42.0                성인
#
# [891 rows x 14 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 성별과 Pclass의 생존률을 피벗 테이블로 만드세요.
# </div>

# %%
df.pivot_table(values='Survived', index='Pclass', columns='Sex')
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: groupby()를 사용하여 각 성별(sex)의 평균 나이(age)를 구하세요.
# </div>

# %%
df[['Sex','Age']].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  28.216730
# male    30.505824

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 전체 승객(passenger)의 평균 생존율을 구하세요.
# </div>

# %%
round(len(df[df['Survived'] == 1]) / len(df['Survived']) * 100)
# Out:
# 38

# %%
round(df['Survived'].mean() * 100)
# Out:
# 38

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 25세 이하 승객의 생존율을 구하세요. (힌트: 불리언 인덱싱)
# </div>

# %%
(len(df['Survived'][(df['Age'] <= 25) & (df['Survived'] == 1)]) / len(df['Survived'][df['Age'] <= 25])) * 100
# Out:
# 41.19601328903654

# %%
round(df.loc[df['Age'] <= 25, 'Survived'].mean() * 100)
# Out:
# 41

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 남성의 생존율을 구하세요. 여성의 생존율을 구하세요. (힌트: 불리언 인덱싱)
# </div>

# %%
display(df[df['Sex'] == 'male'][['Sex', 'Survived']].groupby('Sex').mean())
df[df['Sex'] == 'female'][['Sex', 'Survived']].groupby('Sex').mean()
# Out:
#       Survived
# Sex
# male  0.188908
#         Survived
# Sex
# female  0.742038

# %%
print('남성의 생존률 = ',round(df.loc[df['Sex'] == 'male', 'Survived'].mean() * 100, 3))
# Out:
# 남성의 생존률 =  18.891

# %%
print('여성의 생존률 = ',round(df.loc[df['Sex'] == 'female', 'Survived'].mean() * 100, 3))
# Out:
# 여성의 생존률 =  74.204

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE</b>: 생존율을 구하는 함수가 작성되어 있습니다. 성별 생존율을 groupby를 활용해 구하기 위해 ?부분을 알맞게 채워주세요.
# </div>

# %%
def survival_ratio(survived):
    return survived.sum() / len(survived)

# %%
df[['Sex','Survived']].groupby('Sex').agg(survival_ratio)
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908
